# %% [markdown]
# # Notebook 04 — Feature Engineering
#
# This notebook creates engineered clinical and operational features.
#
# These new variables support clustering, inferential statistics, and the decision-tree model.

# %%
import pandas as pd

file_path = "../data/Krista_240726_Final.xlsx"
med_df = pd.read_excel(file_path, sheet_name="Medication")
med_df.head()

# %% [markdown]
# ## Create engineered features

# %%
# Flag: Was this a wrong-medication event?
med_df['wrong_med_flag'] = med_df['Pattern Specifics'].str.contains('wrong', case=False, na=False)

# Flag: Sedation or analgesia-related medication
sedation_terms = ['ketamine', 'fentanyl', 'midazolam', 'versed']
med_df['sedation_flag'] = med_df['Medication 1'].str.contains('|'.join(sedation_terms), case=False, na=False)

# Flag: Dose-related errors
med_df['dose_error_flag'] = med_df['Pattern Specifics'].str.contains('dose', case=False, na=False)

# Convert Branch to binary: Air = 1, Ground = 0
med_df['branch_air_flag'] = (med_df['Branch'].str.contains('Air', case=False, na=False)).astype(int)

# Display engineered columns
med_df[['wrong_med_flag', 'sedation_flag', 'dose_error_flag', 'branch_air_flag']].head()
