# %% [markdown]
# # Notebook 03 — Bivariate Analysis: Branch and Certificate
#
# This notebook looks at how medication-error patterns vary by Branch (Air vs Ground) and by Certificate.
#
# It uses simple cross-tabulations (crosstabs) to summarize relationships between variables.

# %%
import pandas as pd

file_path = "../data/Krista_240726_Final.xlsx"
med_df = pd.read_excel(file_path, sheet_name="Medication")
med_df.head()

# %%
# Crosstab: Pattern Specifics by Branch
pd.crosstab(med_df['Pattern Specifics'], med_df['Branch'], dropna=False)

# %%
# Crosstab: Pattern Specifics by Certificate (Source)
pd.crosstab(med_df['Pattern Specifics'], med_df['Source'], dropna=False)
