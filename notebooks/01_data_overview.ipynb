# %% [markdown]
# # Notebook 01 — Data Overview
#
# This notebook provides a simple introduction to the dataset, including the number of rows, columns, and a preview of the Medication sheet.
#
# It prepares the foundation for later exploratory analysis.

# %%
import pandas as pd

file_path = "../data/Krista_240726_Final.xlsx"

med_df = pd.read_excel(file_path, sheet_name="Medication")
med_df.head()
