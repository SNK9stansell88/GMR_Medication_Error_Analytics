# %% [markdown]
# # Notebook 02 — Univariate Exploratory Data Analysis (EDA)
#
# This notebook explores the distribution of key variables such as Pattern Specifics, Medication 1, Branch, and Certificate.
#
# These summaries help identify major trends and prepare for deeper analysis.

# %%
import pandas as pd

file_path = "../data/Krista_240726_Final.xlsx"
med_df = pd.read_excel(file_path, sheet_name="Medication")
med_df.head()

# %%
# Frequency of Pattern Specifics
med_df['Pattern Specifics'].value_counts(dropna=False)

# %%
# Frequency of medications involved
med_df['Medication 1'].value_counts(dropna=False)

# %%
# Branch distribution
med_df['Branch'].value_counts(dropna=False)

# %%
# Certificate distribution (Source)
med_df['Source'].value_counts(dropna=False)
